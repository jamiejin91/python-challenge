# %%
import pandas as pd
from sqlalchemy import Column, ForeignKey, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship, Session
from sqlalchemy import create_engine

# %%
df_m_clean = pd.read_csv('Resources/clean_hawaii_measurements.csv')
df_s_clean = pd.read_csv('Resources/clean_hawaii_stations.csv')
df_m_clean.head()
# Out:
#        station      date  prcp  tobs
# 0  USC00519397  20100101  0.08    65
# 1  USC00519397  20100102  0.00    63
# 2  USC00519397  20100103  0.00    74
# 3  USC00519397  20100104  0.00    76
# 4  USC00519397  20100106  0.00    73

# %%
engine = create_engine('sqlite:///hawaii.sqlite', echo=False)
Base = declarative_base()


class Measurement(Base):

    __tablename__ = "measurement"

    id = Column(Integer, primary_key=True)
    station = Column(String(255))
    date = Column(Integer)
    prcp = Column(Float)
    tobs = Column(Integer) 
        
class Station(Base):

    __tablename__ = "station"

    id = Column(Integer, primary_key=True)
    station = Column(String(255))  
    name = Column(String(255))
    latitude = Column(Float)
    longitude = Column(Float)
    elevation = Column(Float)

Base.metadata.create_all(engine)
# Out:
# 2017-10-21 16:39:47,829 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2017-10-21 16:39:47,839 INFO sqlalchemy.engine.base.Engine ()
# 2017-10-21 16:39:47,843 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2017-10-21 16:39:47,846 INFO sqlalchemy.engine.base.Engine ()
# 2017-10-21 16:39:47,850 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("measurement")
# 2017-10-21 16:39:47,853 INFO sqlalchemy.engine.base.Engine ()
# 2017-10-21 16:39:47,862 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("station")
# 2017-10-21 16:39:47,864 INFO sqlalchemy.engine.base.Engine ()
# 2017-10-21 16:39:47,868 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE measurement (
# 	id INTEGER NOT NULL,
# 	station VARCHAR(255),
# 	date INTEGER,
# 	prcp FLOAT,
# 	tobs INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2017-10-21 16:39:47,874 INFO sqlalchemy.engine.base.Engine ()
# ...

# %%
df_m_clean.to_sql('measurement', engine, if_exists='replace')
df_s_clean.to_sql('station', engine, if_exists='replace')
# Out:
# 2017-10-21 16:39:47,973 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("measurement")
# 2017-10-21 16:39:47,975 INFO sqlalchemy.engine.base.Engine ()
# 2017-10-21 16:39:47,986 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("measurement")
# 2017-10-21 16:39:47,990 INFO sqlalchemy.engine.base.Engine ()
# 2017-10-21 16:39:47,999 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2017-10-21 16:39:48,002 INFO sqlalchemy.engine.base.Engine ()
# 2017-10-21 16:39:48,006 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("measurement")
# 2017-10-21 16:39:48,008 INFO sqlalchemy.engine.base.Engine ()
# 2017-10-21 16:39:48,016 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'measurement' AND type = 'table'
# 2017-10-21 16:39:48,020 INFO sqlalchemy.engine.base.Engine ()
# ...
